# %%
# %matplotlib inline

# %%
import pandas as pd
import pyhector
import matplotlib.pyplot as plt

plt.style.use("ggplot")
plt.rcParams.update({'font.size': 22})

# %%
from pandas_datapackage_reader import read_datapackage

from util import root, read_ceds_csv

# %% [markdown]
# Target unit: Mt

# %% [markdown]
# # RCP

# %%
RCP = "RCP"
oc_rcp = pyhector.rcp26.OC_emissions.loc[:2005]

# %% [markdown]
# # CEDS

# %%
CEDS = "CEDS"
# Unit in CEDS: KtBC, Hector: Mt, MAGICC: Mt
ceds_oc = read_ceds_csv(
    root / "data/ceds/OC_CEDS_emissions_by_country_v2016_07_26.csv")
oc_ceds = ceds_oc / 1000  # kt -> Mt

# %% [markdown]
# # Figure

# %%
lw = 3
oc_ceds.plot(label=CEDS, linewidth=lw)
oc_rcp.plot(label=RCP, linewidth=lw)
plt.title("Global OC Emissions [Mt]")
plt.legend()
plt.xlabel("")
plt.savefig(
    root / "content/images/global-oc.png",
    bbox_inches="tight", 
    pad_inches=0
)
